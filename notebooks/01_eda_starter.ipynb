# %% [markdown]
# # Curtailment EDA starter
# Replace the demo dataset with the normalized official competition dataset when available.

# %%
import pandas as pd
df = pd.read_csv('../data/demo/curtailment_demo.csv')
df.head()
